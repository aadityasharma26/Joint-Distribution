# %% [markdown]
# ##**Session flow:**
#
# 👨🏻‍🎓 Learning Objective:
#
# * Introduction
# * Theme
# * Primary Goals
#
# 📙 Joint probability mass function
#
# ✍ Joint cumulative distribution function
#
# * Activity 1
#
# 📚 Joint probability density function
#
# 🧑 Distribution
# * Conditional
# * Marginal
# * Activity 2
#
# ✏ Covariance and corelation
#
# 🖊 Mulitvariate normal distribution
#
# * Activity 3
#
# 📝 Summary
#
# * What did we learn?
# * Shortcomings & Challenges
# * Best Practices & Tips
#
# 🔗 Enhance your Knowledge
#
# * Mnemonic
# * Additional Resources
#
# 🔍 Try it Yourself
#
# * Activities
# * Social Engagement

# %% [markdown]
# ## **👨🏻‍🎓 Learning Objective 👨🏻‍🎓**

# %% [markdown]
# ## **Introduction:**
#
# 📢 Hey there, Students! 📚
#
# I'm thrilled to let you know that we'll be delving into the exciting world of joint distribution. This topic is fundamental in probability theory and statistics, and it plays a significant role in numerous fields, such as finance, engineering, and social sciences.
#
# So, what can you expect to learn in this topic? Let me give you a brief overview.
#
# 🤝 Joint probability mass function and joint cumulative distribution function: In joint distribution, we are interested in analyzing the behavior of two or more random variables simultaneously. We use joint probability mass function and joint cumulative distribution function to study the joint behavior of discrete random variables.
#
# 📈 Joint probability density function: When dealing with continuous random variables, we use the joint probability density function to describe their behavior.
#
# 🔍 Marginal distribution: Marginal distribution helps us to study the behavior of a single random variable from a joint distribution.
#
# 🎯 Conditional distribution: Conditional distribution allows us to examine the behavior of a random variable given that we have information about another random variable.
#
# 💞 Covariance and correlation: Covariance and correlation measure the relationship between two random variables in a joint distribution.
#
# 🌟 Multivariate normal distribution: Finally, we'll explore the multivariate normal distribution, which is one of the essential distributions in probability theory and statistics.
#
# I hope this brief overview of the topics we'll cover in joint distribution has gotten you excited to start exploring! 🤩

# %% [markdown]
# ##**Theme**
#
# Joint distributions are of paramount importance in the realm of probability and statistics as they allow us to explore the intricate relationships between multiple random variables. By capturing the simultaneous behavior of two or more variables, joint distributions provide a comprehensive view of how these variables interact and influence each other. This is crucial for understanding complex systems and making informed decisions. Whether it's assessing the correlation between economic indicators, analyzing the joint performance of assets in finance, or examining the co-occurrence of events in various fields, joint distributions unveil hidden patterns and dependencies that might be missed when studying variables in isolation. Moreover, joint distributions serve as building blocks for calculating other vital statistical quantities, such as conditional probabilities and expectations. They provide a powerful tool for modeling, prediction, and risk assessment, contributing to better-informed choices and a deeper understanding of the underlying mechanisms governing diverse phenomena.

# %% [markdown]
# ## **Primary Goals:**
#
# 🎯 Here are the primary goals we'll achieve in our joint distribution lesson:
#
# 🤝 Understanding joint probability mass function and joint cumulative distribution function and applying them to analyze the joint behavior of discrete random variables.
#
# 📈 Understanding joint probability density function and using it to analyze the joint behavior of continuous random variables.
#
# 🔍 Understanding marginal distribution and using it to study the behavior of a single random variable from a joint distribution.
#
# 🎯 Understanding conditional distribution and using it to examine the behavior of a random variable given that we have information about another random variable.
#
# 💞 Understanding covariance and correlation and using them to measure the relationship between two random variables in a joint distribution.
#
# 🌟 Understanding the multivariate normal distribution and using it to model the behavior of multiple random variables.
#
# By achieving these goals, you'll have a comprehensive understanding of joint distribution and its applications in various fields. Let's get started on this exciting journey! 🚀

# %% [markdown]
# # **📖 Learning Material 📖**

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# 👋 Hello! Joint distribution is an important concept in probability theory and statistics, and it refers to the distribution of two or more random variables together. Here are some key points to keep in mind:
#
# **🤝 Joint probability mass function:**
#
# If we have two discrete random variables, their joint distribution can be described by a joint probability mass function, which gives the probability of each possible combination of values for the two variables.
#
# **📈 Joint probability density function:**
#
# If we have two continuous random variables, their joint distribution can be described by a joint probability density function, which gives the probability density at each point in the joint space.

# %% [markdown]
# ***💻 Code examples: Here's an example of how to define a joint probability mass function for two discrete random variables X and Y in Python:***

# %%
import numpy as np

# Define the joint probability mass function
joint_pmf = np.array([[0.1, 0.2, 0.05],
                      [0.05, 0.15, 0.2],
                      [0.05, 0.1, 0.1]])

# Print the joint probability mass function
print(joint_pmf)
# Out:
# [[0.1  0.2  0.05]
#  [0.05 0.15 0.2 ]
#  [0.05 0.1  0.1 ]]

# %% [markdown]
# And here's an example of how to define a joint probability density function for two continuous random variables X and Y in Python:

# %%
import numpy as np

# Define the joint probability density function
def joint_pdf(x, y):
    return np.exp(-(x**2 + y**2)) / (2 * np.pi)

# Evaluate the joint probability density function at some points
print(joint_pdf(0.5, 0.5))
print(joint_pdf(1, 2))
# Out:
# 0.09653235263005391
# 0.0010723775711956546

# %% [markdown]
# **🔍 Marginal distribution:**
#
# The marginal distribution of a single random variable can be obtained from the joint distribution by summing (in the case of discrete variables) or integrating (in the case of continuous variables) over the other variable(s).
#
# Let's break it down further:
#
# **Discrete Variables**: If you have a joint probability distribution for two or more discrete random variables, you can obtain the marginal distribution of one of those variables by summing the joint probabilities over all possible values of the other variable(s). This effectively "marginalizes out" the other variable(s), leaving you with the distribution of the variable of interest.
#
# Mathematically, if you have a joint distribution P(X, Y) for discrete variables X and Y, then the marginal distribution P(X) can be obtained by summing over all possible values of Y:
#
# P(X) = ∑ P(X, y) for all y
#
# **Continuous Variables**: Similarly, for continuous random variables, you would integrate the joint probability density function over the entire range of values of the other variable(s) to obtain the marginal density function of the variable of interest.
#
# Mathematically, if you have a joint density function f(X, Y) for continuous variables X and Y, then the marginal density function f(X) can be obtained by integrating over the entire range of Y:
#
# f(X) = ∫ f(X, y) dy for all y
#
# In both cases, the resulting marginal distribution or density function will satisfy the properties of a valid probability distribution: it will be non-negative, and the total probability (or density) will sum (or integrate) to 1.
#
# **📉 Conditional distribution:**
#
# The conditional distribution of one random variable given another can also be obtained from the joint distribution by dividing by the marginal distribution of the conditioning variable.
#
# Let's delve into this further:
#
# **Discrete Variables**: Suppose you have two discrete random variables, X and Y, and you want to find the conditional distribution of X given a particular value y of Y. You can do this by dividing the joint probability P(X, Y) by the marginal probability P(Y = y):
#
# P(X = x | Y = y) = P(X = x, Y = y) / P(Y = y)
#
# Here, P(X = x, Y = y) is the joint probability of X and Y taking on specific values x and y, and P(Y = y) is the marginal probability of Y taking on the value y.
#
# **Continuous Variables**: Similarly, if you have two continuous random variables, X and Y, and you want to find the conditional density of X given a particular value y of Y, you can divide the joint density f(X, Y) by the marginal density f_Y(y):
#
# f(X = x | Y = y) = f(X = x, Y = y) / f_Y(y)
#
# Here, f(X = x, Y = y) is the joint density of X and Y, and f_Y(y) is the marginal density of Y.
#
# This process of obtaining conditional distributions is known as conditional probability or conditional density, and it allows you to analyze how one random variable behaves given specific information about another random variable.
#
# **💡 Applications:**
#
# Joint distribution is used in a variety of fields, including engineering, physics, and finance, to model the relationships between multiple random variables and make predictions or decisions based on those relationships.

# %% [markdown]
# ##**Joint Probability Mass Function**

# %% [markdown]
# **🎓 Joint Probability Mass Function (Joint PMF) 🎓**
#
# In probability theory, a joint probability mass function is a function that gives the probability that two discrete random variables X and Y are equal to particular values, denoted by P(X = x, Y = y). Here are some important points to know about Joint PMF:
#
# 🔹 Joint PMF is a function that maps each pair of values (x,y) from the joint domain of X and Y to the probability that X = x and Y = y.
#
# 🔹 The joint PMF must satisfy two properties: non-negativity and summation.
#
# 🔹 The sum of all the probabilities in the joint PMF over all possible values of X and Y must be equal to 1.
#
# 🔹 Joint PMF can be used to calculate marginal probabilities, which are probabilities of individual random variables.
#
# 🔹 Joint PMF can also be used to calculate conditional probabilities, which are probabilities of one random variable given that another random variable has a particular value.
#
# 🔹 Joint PMF is often visualized using a joint probability table or a heatmap.
#
# 🔹 In code, joint PMF can be defined using a two-dimensional array or a dictionary of tuples.

# %% [markdown]
# ***Here's an example code snippet in Python to calculate joint PMF:***

# %%
import numpy as np

# Define the joint PMF as a 2D array
joint_pmf = np.array([[0.1, 0.2, 0.05],
                      [0.05, 0.15, 0.2],
                      [0.05, 0.1, 0.1]])

# Calculate the marginal PMF of X by summing over Y
marginal_pmf_x = np.sum(joint_pmf, axis=1)

# Calculate the conditional PMF of Y given X=2
conditional_pmf_y_given_x2 = joint_pmf[2, :] / marginal_pmf_x[2]

# Print the results
print("Joint PMF:")
print(joint_pmf)
print("Marginal PMF of X:")
print(marginal_pmf_x)
print("Conditional PMF of Y given X=2:")
print(conditional_pmf_y_given_x2)
# Out:
# Joint PMF:
# [[0.1  0.2  0.05]
#  [0.05 0.15 0.2 ]
#  [0.05 0.1  0.1 ]]
# Marginal PMF of X:
# [0.35 0.4  0.25]
# Conditional PMF of Y given X=2:
# [0.2 0.4 0.4]

# %% [markdown]
# ## **Joint Cumulative Distribution Function**

# %% [markdown]
# **📈🎲🔢 Introduction to Joint Cumulative Distribution Function:**
#
# In probability theory and statistics, the joint cumulative distribution function (CDF) is a function that gives the probability that two or more random variables in a probability distribution take on specific values or fall within specified ranges simultaneously. It is defined as the probability of the event {X ≤ x, Y ≤ y}, where X and Y are two random variables, and x and y are values.
#
# **📈📊🔢 Properties of Joint Cumulative Distribution Function:**
#
# 1. Joint CDF is always non-negative and takes values between 0 and 1.
#
# 2. It is a monotonically non-decreasing function in both of its arguments.
#
# 3. The joint CDF approaches 0 as both of its arguments approach negative infinity.
#
# 4. The joint CDF approaches 1 as both of its arguments approach positive infinity.
#
# **📈🎲🔢 Examples of Joint Cumulative Distribution Function:**
#
# Suppose we have two discrete random variables X and Y. The joint CDF for X and Y can be defined as:
#
# F(x,y) = P(X ≤ x, Y ≤ y)

# %% [markdown]
# **📈💻🔢 Code Examples:**
#
# The joint CDF can be calculated using Python's scipy.stats module. Here's an example code:

# %% [markdown]
# ```
# from scipy.stats import randint
#
# xk = [1, 2, 3, 4, 5, 6]
# pk = [1/6, 1/6, 1/6, 1/6, 1/6, 1/6]
# X = randint(a=1, b=7)
# Y = randint(a=1, b=7)
#
# # Calculate joint CDF for X and Y
# F = lambda x, y: X.cdf(x)*Y.cdf(y)
#
# # Calculate joint CDF for x = 3, y = 4
# F(3, 4)
#
# ```

# %% [markdown]
# This code generates two discrete random variables X and Y with uniform probability distribution between 1 and 6. Then it defines a lambda function F to calculate the joint CDF for X and Y. Finally, it calculates the joint CDF for x = 3 and y = 4.

# %% [markdown]
# ##**Activity: True or false**
#
# Statement 1: The Joint Probability Mass Function (Joint PMF) of two discrete random variables provides the probability that both variables take specific values simultaneously.
#
# Statement 2: The Joint Cumulative Distribution Function (Joint CDF) of two random variables gives the probability that one variable is less than or equal to a specific value, while the other variable is greater than or equal to another specific value.

# %% [markdown]
# ## **Joint Probability Density Function**

# %% [markdown]
# 📈🔍📊🔮
#
# Joint Probability Density Function (PDF) is a function that describes the probability of multiple random variables taking specific values simultaneously. It is used in continuous probability distributions to model the likelihood of two or more variables occurring together.
#
# **Here are some important points regarding Joint PDF:**
#
# **1. Definition:**
#
# The Joint Probability Density Function is a function of two or more variables that define the probability of those variables taking specific values simultaneously.
#
# **2. Properties:**
#
# The joint PDF must satisfy certain properties, such as non-negativity and the integral over the entire domain equals to one.
#
# **3. Interpretation:**
#
# The value of the joint PDF at any point (x, y) represents the likelihood of the variables X and Y taking on values close to x and y, respectively.
#
# **4. Relationship with Marginal PDFs:**
#
# By integrating the joint PDF over one of the variables, we obtain the marginal PDF for the other variable.
#
# **5. Relationship with Joint CDF:**
#
# The joint PDF is related to the joint CDF by taking the partial derivative with respect to each variable.
#
# **6. Examples:**
#
# Some examples of probability distributions that have a joint PDF include the bivariate normal distribution and the joint uniform distribution.

# %% [markdown]
# ***Here is an example of how to plot the Joint PDF of two random variables using Python and the matplotlib library:***

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the joint PDF function
def joint_pdf(x, y):
    return 3*(1-x**2)*y**2*np.exp(-(x**2+y**2)/2)

# Create a grid of x and y values
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)

# Evaluate the joint PDF at each point in the grid
Z = joint_pdf(X, Y)

# Plot the Joint PDF as a contour plot
plt.contour(X, Y, Z)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Joint PDF of X and Y')
plt.show()

# %% [markdown]
# This code creates a contour plot of the Joint PDF of two random variables X and Y, with X values ranging from -3 to 3 and Y values ranging from -3 to 3. The joint PDF function is defined using the input variables x and y, and the plot is generated using the contour function from the matplotlib library. The resulting plot shows the contours of the Joint PDF, with darker regions indicating higher probability density.

# %% [markdown]
# ## **Marginal Distribution**

# %% [markdown]
# 📊 Marginal distribution refers to the probability distribution of one or more variables in a joint probability distribution.
#
# 📊 The marginal distribution is obtained by summing (or integrating, in the case of continuous variables) the joint probability distribution over the variables not of interest.
#
# 📊 Marginal distributions can be calculated for both discrete and continuous variables.
#
# 📊 Marginal distribution is useful in simplifying the analysis of complex problems that involve multiple variables.
#
# 📊 The marginal distribution of a single variable can be obtained by summing (or integrating) the joint distribution over all possible values of the other variables.
#
# 📊 The marginal distribution of multiple variables can be obtained by summing (or integrating) the joint distribution over all possible values of the variables not of interest.
#
# 📊 Marginal distributions are important in statistics, as they allow us to study the behavior of individual variables in a multivariate distribution.
#
# 📊 In Python, the marginal distribution can be calculated using the numpy.sum() function for discrete variables and scipy.integrate.simps() function for continuous variables. Here's an example:

# %%
import numpy as np
import scipy.integrate as spi

# Define the joint probability density function
def joint_pdf(x, y):
    return x*y*np.exp(-x*y)

# Define the marginal probability density function for x
def marginal_pdf_x(x):
    return spi.simps(joint_pdf(x, y_vals), y_vals)

# Define the marginal probability density function for y
def marginal_pdf_y(y):
    return spi.simps(joint_pdf(x_vals, y), x_vals)

# Define the range of values for x and y
x_vals = np.linspace(0, 5, 50)
y_vals = np.linspace(0, 5, 50)

# Calculate the marginal PDFs for x and y
marginal_x = np.array([marginal_pdf_x(x) for x in x_vals])
marginal_y = np.array([marginal_pdf_y(y) for y in y_vals])

# %% [markdown]
# 📊 The resulting arrays marginal_x and marginal_y contain the marginal probability density functions for the variables x and y, respectively.

# %% [markdown]
# ## **Conditional Distribution**

# %% [markdown]
# **🎓 Introduction to Conditional Distribution:**
#
# Conditional distribution is a concept in probability theory that involves calculating the probability distribution of a random variable given that another random variable takes a certain value. It is a way to understand how the probability distribution of one variable changes when another variable is known or fixed.
#
# **🔍 Conditional Probability:**
#
# Conditional probability is the probability of an event occurring given that another event has occurred. It is defined as the probability of event A occurring given that event B has already occurred and is denoted by P(A|B).
#
# **🔍 Conditional Probability Mass Function (PMF):**
#
# In the case of discrete random variables, the conditional probability mass function (PMF) gives the probability of a particular value of the random variable, given that another random variable takes a certain value. It is denoted by P(X = x|Y = y).
#
# **🔍 Conditional Probability Density Function (PDF):**
#
# For continuous random variables, the conditional probability density function (PDF) gives the probability density of a particular value of the random variable, given that another random variable takes a certain value. It is denoted by f(x|y).
#
# **📈 Examples:**
#
# Suppose we have two random variables X and Y, and we want to find the conditional probability of X given that Y takes a certain value y. We can use the conditional probability formula:
#
# P(X=x|Y=y) = P(X=x, Y=y) / P(Y=y)
#
# where P(X=x, Y=y) is the joint probability of X and Y taking the values x and y respectively, and P(Y=y) is the marginal probability of Y taking the value y.
#
# ***Example code for calculating the conditional PMF of X given Y = y:***

# %%
# Define the joint PMF of X and Y
pmf_XY = {(0, 1): 0.1, (1, 1): 0.3, (0, 2): 0.2, (1, 2): 0.4}

# Define the marginal PMF of Y
pmf_Y = {1: 0.4, 2: 0.6}

# Calculate the conditional PMF of X given Y=1
pmf_X_given_Y1 = {(0): pmf_XY[(0, 1)] / pmf_Y[1], (1): pmf_XY[(1, 1)] / pmf_Y[1]}

# Calculate the conditional PMF of X given Y=2
pmf_X_given_Y2 = {(0): pmf_XY[(0, 2)] / pmf_Y[2], (1): pmf_XY[(1, 2)] / pmf_Y[2]}

# %% [markdown]
# **🧐 Importance:**
#
# Conditional distribution is an important concept in probability theory and has many practical applications, such as in statistical inference, data analysis, and machine learning. It allows us to model complex systems by understanding how one variable affects another, and it is used in a wide range of fields such as finance, healthcare, and engineering.

# %% [markdown]
# ##**Activity: Guess the word**
#
# **Riddle 1:**
#
# In the world of probabilities, I play a role,
# Unraveling insights, a tale to unfold.
# When focus narrows, and one variable shines,
# From a joint distribution, I emerge in defined lines.
#
# A slice of the whole, a story in part,
# In the grand chart of numbers, I take a smart start.
# Summing my rows or columns with care
#
# What am I?
#
#
# **Riddle 2:**
#
# In the realm of probabilities, a dynamic duo I trace,
# Two variables entwined, their paths I embrace.
# For every pair of outcomes, a number I display,
# In a world of statistics, I have a significant role to convey.
#
# Graphing the relationships, I lay them bare,
# Mapping joint probabilities with precision and care.
# Side by side, variables align and unfold,
#
# What am I?

# %% [markdown]
# ## **Covariance and Correlation**

# %% [markdown]
# **🎓 Introduction:**
#
# Covariance and correlation are two statistical concepts that measure the relationship between two variables. Covariance is a measure of how two variables change together, while correlation is a measure of the strength of their linear relationship. Both are important tools in data analysis and can help us understand the relationship between different variables.
#
# **📊 Covariance:**
#
# Covariance is a measure of how two variables vary together. It measures the degree to which two variables are related to each other. A positive covariance means that the two variables tend to move in the same direction, while a negative covariance means they tend to move in opposite directions. Covariance is sensitive to the scale of the variables and is not standardized.
#
# **🔍 Formula:**
#
# Covariance can be calculated using the following formula:
# $cov(X,Y) = E[(X - E[X])(Y - E[Y])]$
#
# **📈 Correlation:**
#
# Correlation measures the strength of the linear relationship between two variables. It ranges from -1 to 1, where -1 indicates a perfectly negative correlation, 0 indicates no correlation, and 1 indicates a perfectly positive correlation. Correlation is standardized, which means it is not sensitive to the scale of the variables.
#
# **🔍 Formula:**
#
# Correlation can be calculated using the following formula:
# $corr(X,Y) = cov(X,Y) / (std(X) * std(Y))$
#
# **👥 Interpretation:**
#
# A positive covariance or correlation indicates that two variables tend to move in the same direction, while a negative covariance or correlation indicates that they tend to move in opposite directions. A correlation of 0 indicates no linear relationship between the variables. The strength of the correlation can be interpreted using the correlation coefficient.

# %% [markdown]
# **📊 Code Examples:**
#
# ***Here is an example of how to calculate covariance and correlation using Python:***

# %%
import numpy as np

# Sample data
X = np.array([1, 2, 3, 4, 5])
Y = np.array([5, 4, 3, 2, 1])

# Calculate covariance
covariance = np.cov(X, Y)[0][1]

# Calculate correlation
correlation = np.corrcoef(X, Y)[0][1]

print("Covariance:", covariance)
print("Correlation:", correlation)
# Out:
# Covariance: -2.5
# Correlation: -0.9999999999999999

# %% [markdown]
# ## **Multivariate Normal Distribution**

# %% [markdown]
# Multivariate normal distribution is a powerful concept in probability theory, which allows us to model the behavior of multiple random variables that are jointly normally distributed. Here are some important points to keep in mind:
#
# **Definition:**
#
# Multivariate normal distribution is a continuous probability distribution of multiple random variables, where each variable follows a normal distribution, and all variables are correlated with each other. It is also known as a multivariate Gaussian distribution.
#
# **Parameters:**
#
# A multivariate normal distribution is characterized by two parameters: a mean vector μ, which specifies the center of the distribution, and a covariance matrix Σ, which describes the spread and correlation of the variables.
#
# Probability Density Function: The probability density function (PDF) of a multivariate normal distribution is given by:
#
# $f(x) = (2π)⁻ᵏ/²|Σ|⁽¹/²⁾ exp(-(1/2)(x-μ)ᵀΣ⁻¹(x-μ))$
#
# where x is a k-dimensional vector of random variables, |Σ| is the determinant of the covariance matrix, Σ⁻¹ is the inverse of the covariance matrix, and ᵀ denotes the transpose.
#
# **Properties:**
#
# Some important properties of multivariate normal distributions include:
#
# 1. Any linear transformation of a multivariate normal distribution is also a multivariate normal distribution.
#
# 2. The conditional distribution of a subset of variables given the remaining variables is also a multivariate normal distribution.
#
# 3. The marginal distribution of a subset of variables is also a multivariate normal distribution.
#
# **Applications:**
#
# Multivariate normal distributions are widely used in many fields, including finance, economics, and engineering, for modeling complex systems with multiple variables.

# %% [markdown]
# ***Here's an example of how to generate a multivariate normal distribution in Python using the numpy library:***

# %%
import numpy as np

# define the mean vector and covariance matrix
mu = np.array([0, 0])
cov = np.array([[1, 0.5], [0.5, 2]])

# generate a random sample from the distribution
sample = np.random.multivariate_normal(mu, cov, size=1000)

# plot the sample using matplotlib
import matplotlib.pyplot as plt
plt.scatter(sample[:, 0], sample[:, 1])
plt.show()

# %% [markdown]
# ##**Activity: Fill in the Blanks**
#
# In the realm of statistical analysis, the concepts of covariance, correlation, and multivariate normal distribution intertwine to give the relationships and dependencies between multiple variables.
#
# (1) _________ measures how two variables vary together; a positive value indicates they tend to increase or decrease simultaneously, while a negative value suggests an inverse relationship. It's a measure of the joint variability between variables, capturing their joint movements.
#
# (2) _________ goes a step further, standardizing the covariance to a range between -1 and 1, allowing for easier comparison. A correlation of 1 signifies a perfect positive linear relationship, -1 indicates a perfect negative linear relationship, and 0 suggests no linear relationship.
#
# When dealing with multiple variables, the (3) _________ emerges as a powerful tool. It extends the normal distribution to more than two dimensions, providing a way to model the joint behavior of several variables. Each variable follows a normal distribution, while the interplay between variables is captured by their means, variances, and covariances. This distribution is widely used in various fields, from finance to biology, as it simplifies complex systems and allows for precise probability calculations.

# %% [markdown]
# ## **Conclusion**

# %% [markdown]
# 🔹 Joint Distribution is an important concept in probability theory and statistics that deals with the probability of two or more random variables occurring together.
#
# 🔹 It involves understanding the joint probability mass function, joint probability density function, joint cumulative distribution function, and conditional distribution.
#
# 🔹 The relationship between random variables can be explored using covariance and correlation.
#
# 🔹 Multivariate normal distribution is an example of joint distribution, which is commonly used in statistical inference and modeling.
#
# 🔹 Joint distribution can be used in various applications such as in finance, economics, engineering, and social sciences.
#
# 🔹 Understanding joint distribution is crucial for conducting hypothesis testing, building regression models, and making predictions in various fields.
#
# 🔹 Python provides several packages such as NumPy, SciPy, and Pandas for working with joint distributions, calculating their properties, and visualizing them.

# %% [markdown]
# ***Example of code sample:***

# %%
import numpy as np
from scipy.stats import multivariate_normal

# Generate random data
x = np.random.normal(0, 1, 100)
y = np.random.normal(0, 1, 100)
data = np.column_stack((x, y))

# Calculate mean and covariance matrix
mean = np.mean(data, axis=0)
cov = np.cov(data.T)

# Create a multivariate normal distribution
mnorm = multivariate_normal(mean=mean, cov=cov)

# Calculate probability density function at a point
point = [0.5, 0.5]
pdf = mnorm.pdf(point)
print(f"PDF at {point}: {pdf}")

# Generate random samples from the distribution
samples = mnorm.rvs(10)
print(f"Random samples:\n{samples}")
# Out:
# PDF at [0.5, 0.5]: 0.11812966431929475
# Random samples:
# [[-0.80140186 -0.25651728]
#  [ 1.80605079 -0.06790699]
#  [ 0.73175127  0.81316007]
#  [ 0.21497386  0.85520121]
#  [-0.8825205   0.75343937]
#  [-1.79461107  0.88738634]
#  [-0.72071179  0.76029105]
#  [ 3.29273388  0.04238888]
#  [-0.63726165  0.23552389]
#  [ 0.93815133 -0.64589541]]

# %% [markdown]
# This code generates random data from a multivariate normal distribution, calculates its mean and covariance matrix, creates a multivariate_normal object using these parameters, calculates the probability density function at a point, and generates random samples from the distribution. This is just a simple example to demonstrate how joint distribution can be used in Python programming.

# %% [markdown]
# # **✅ Summary ✅**

# %% [markdown]
# ###🎓 **What did you learn ?** 🤔
#
# 🤝 Joint probability mass function and joint cumulative distribution function are used to analyze the joint behavior of discrete random variables.
#
# 📈 Joint probability density function is used to analyze the joint behavior of continuous random variables.
#
# 🔍 Marginal distribution helps us study the behavior of a single random variable from a joint distribution.
#
# 🎯 Conditional distribution allows us to examine the behavior of a random variable given that we have information about another random variable.
#
# 💞 Covariance and correlation measure the relationship between two random variables in a joint distribution.
#
# 🌟 The multivariate normal distribution is used to model the behavior of multiple random variables.
#
# Overall, joint distribution is a crucial topic in probability theory and statistics. By understanding these concepts, you can apply them in various fields such as finance, engineering, and social sciences. Keep practicing and applying these concepts, and you'll soon become a joint distribution expert! 🚀

# %% [markdown]
# ###👍 **Best Practices and Tips**
#
# 📚 Practice as much as you can. Solve as many problems as possible to get a better understanding of the concepts.
#
# 🤔 Understand the underlying theory. Try to understand the intuition behind each concept.
#
# 🧮 Don't just memorize formulas. Understand how to apply them and when to use them.
#
# 📊 Visualize the data. Draw diagrams and graphs to help you understand the behavior of random variables.
#
# 🔍 Pay attention to details. Keep track of the assumptions made in each concept and make sure you satisfy them.
#
# 💻 Use software tools. Use software like R, Python, or Matlab to visualize and analyze the data.
#
# 👥 Collaborate with others. Work with your peers to solve problems and gain a deeper understanding of the concepts.
#
# By following these tips, you can improve your understanding of joint distribution and develop your skills in probability theory and statistics. Good luck! 🚀

# %% [markdown]
# ###👎 **Shortcomings**
#
# 📉 Lack of practice. Without practice, it can be challenging to fully understand and apply the concepts.
#
# 🤯 Overcomplicating the theory. It's important to focus on the fundamental principles and not get bogged down in complex formulas.
#
# 👀 Ignoring the details. Small details, such as assumptions and conditions, can significantly impact the analysis results.
#
# 📈 Relying too much on software. While software tools can be helpful, it's essential to understand the concepts and not just rely on the software output.
#
# 🤝 Failing to collaborate. Working with peers can provide different perspectives and help you gain a deeper understanding of the concepts.
#
# 📊 Neglecting visualization. Visual aids, such as diagrams and graphs, can help you understand and communicate the data better.
#
# By avoiding these shortcomings, you can develop a stronger foundation in joint distribution and excel in probability theory and statistics.

# %% [markdown]
# # **➕ Additional Reading ➕**

# %% [markdown]
# ### **Mnemonic:**
#
# 📚 Once upon a time, there were three friends named Alice, Bob, and Charlie. They loved solving puzzles and playing games, but their favorite was playing dice games.
#
# One day, they found a new game that required them to roll two dice and find the sum of their numbers. They decided to play and keep track of their results.
#
# After several games, they wondered if they could use joint distribution concepts to analyze their results. They knew that the sum of the numbers on the two dice was a joint distribution of discrete random variables, and they could use the joint probability mass function to study its behavior.
#
# They calculated the joint probability mass function of their dice game results and found that they had a higher chance of getting a sum of 7 or 11 than any other number. They also used the marginal distribution to analyze the behavior of a single die, and the conditional distribution to calculate the probability of getting a certain sum given that they knew one of the dice's numbers.
#
# Excited about their findings, they decided to explore more complex games. They found a new game where they had to roll two dice and find the product of their numbers. They knew that the product of the numbers on the two dice was a joint distribution of continuous random variables, and they could use the joint probability density function to study its behavior.
#
# They calculated the joint probability density function of their new game results and found that they had a higher chance of getting a product between 6 and 12 than any other value. They also used covariance and correlation to measure the relationship between the two dice's numbers.
#
# After spending hours analyzing their games, Alice, Bob, and Charlie had a great time exploring the world of joint distribution. They had fun solving puzzles and games while applying their knowledge of joint distribution concepts.
#
# In the end, they concluded that understanding joint distribution concepts could help them win more games and solve more complex puzzles. They couldn't wait to use their new knowledge to tackle more exciting challenges in the future. 🤓

# %% [markdown]
# ###📚 **Additional Resources**
#
# 🔍 Read textbooks and articles on probability theory and statistics. Some popular books include "Probability and Statistics" by Morris DeGroot and Mark Schervish, "An Introduction to Probability Theory and Its Applications" by William Feller, and "Probability and Random Processes" by Geoffrey Grimmett and David Stirzaker.
#
# 🎥 Watch online lectures and tutorials. Websites like Khan Academy, Coursera, and edX offer free online courses on probability theory and statistics.
#
# 🔢 Solve practice problems and exercises. Websites like Brilliant.org and Project Euler offer challenging problems that can help you sharpen your problem-solving skills.
#
# 📊 Conduct data analysis projects. Use software like R, Python, or Matlab to analyze real-world data and apply the concepts you've learned in class.
#
# 👥 Join study groups or online forums. Collaborate with peers and ask for help when you encounter difficulties.
#
# By engaging in these additional reading and activities, you can further develop your understanding of joint distribution and probability theory. Good luck! 🚀
#
# Additional reading:
#
# 1. https://www.researchgate.net/publication/24120229_Methods_for_Estimating_a_Conditional_Distribution_Function
# 2. https://www.simplilearn.com/covariance-vs-correlation-article

# %% [markdown]
# # **Try it Yourself 📃**
#
# Are you ready to put your skills to the test and gain practical knowledge? We have some exciting questions waiting for you to solve! 🚀
#
# Your task is to attempt the coding questions associated with this lesson. These challenges have been thoughtfully designed to reinforce your understanding of the concepts covered in the course. You can find them in your dashboard under this lesson.
#
# Don't be shy! Share your findings, experiences, and any insights you gained while tackling these coding questions on the AlmaBetter community platform. Engage in discussions, help each other out, and celebrate your victories together!
#
# Remember, It's not just about learning theory; it's about applying that knowledge to solve real-world problems. So, dive in, experiment, and have fun while honing your coding skills!
# Let's learn, grow, and inspire each other as a vibrant community of passionate learners. Happy Learning! 💻 😊

# %% [markdown]
# ## **Task 1**

# %% [markdown]
# ### **🎓 Activity 1:**

# %% [markdown]
# A group of students measured the height and weight of 10 classmates. The data is given in the following table:
#
# | Student | Height (inches) | Weight (pounds) |
# | ------- | --------------- | --------------- |
# | 1       | 68              | 165             |
# | 2       | 71              | 201             |
# | 3       | 61              | 140             |
# | 4       | 72              | 210             |
# | 5       | 67              | 165             |
# | 6       | 64              | 125             |
# | 7       | 65              | 150             |
# | 8       | 62              | 120             |
# | 9       | 66              | 160             |
# | 10      | 69              | 186             |
#
#
#
#
#
# a) Calculate the covariance between height and weight.

# %%
import numpy as np

# Data
height = np.array([68, 71, 61, 72, 67, 64, 65, 62, 66, 69])
weight = np.array([165, 201, 140, 210, 165, 125, 150, 120, 160, 186])

# Calculate Mean

mean_height = np.mean(height)
mean_weight = np.mean(weight)

# Calculate covariance

covariance = np.mean((height - mean_height) * (weight - mean_weight))

# Output

print("Covariance between height and weight: ", covariance)
# Out:
# Covariance between height and weight:  92.7

# %% [markdown]
# ### **🎓 Activity 2:**

# %% [markdown]
# Suppose you are a teacher and you have a class of 30 students. You know that the students' heights are normally distributed with mean $\mu=64$ inches and standard deviation $\sigma=3$ inches. Additionally, you know that the heights of the female students in the class are also normally distributed with mean $\mu_f=62$ inches and standard deviation $\sigma_f=2.5$ inches.
#
# a) If a student is chosen at random from the class, what is the probability that their height is between 62 and 66 inches?
#
# b) If you randomly select a female student from the class, what is the probability that her height is between 60 and 64 inches?

# %%
from scipy.stats import norm

# Parameters for the entire class
mu = 64  # Mean height in inches
sigma = 3  # Standard deviation in inches

# Parameters for female students
mu_f = 62  # Mean height for females in inches
sigma_f = 2.5  # Standard deviation for females in inches

# (a) Probability that a randomly chosen student's height is between 62 and 66 inches
p_a = norm.cdf(66, loc=mu, scale=sigma) - norm.cdf(62, loc=mu, scale=sigma)

# (b) Probability that a randomly chosen female student's height is between 60 and 64 inches
p_b = norm.cdf(64, loc=mu_f, scale=sigma_f) - norm.cdf(60, loc=mu_f, scale=sigma_f)

# Output results
print("(a) Probability that a student's height is between 62 and 66 inches:", p_a)
print("(b) Probability that a female student's height is between 60 and 64 inches:", p_b)
# Out:
# (a) Probability that a student's height is between 62 and 66 inches: 0.4950149249061542
# (b) Probability that a female student's height is between 60 and 64 inches: 0.5762892028332067

# %% [markdown]
# ### **🎓 Activity 3:**

# %% [markdown]
# Suppose the heights and weights of a group of 50 students are jointly distributed according to a bivariate normal distribution with mean vector $\boldsymbol{\mu} = \begin{bmatrix} 65 \\ 150 \end{bmatrix}$ and covariance matrix $\boldsymbol{\Sigma} = \begin{bmatrix} 9 & 24 \\ 24 & 64 \end{bmatrix}$.
#
#
# What is the probability that a randomly selected student has a height between 62 and 68 inches and a weight between 140 and 160 pounds?

# %%
import numpy as np
from scipy.stats import multivariate_normal

# Mean vector (mu) and covariance matrix (Sigma)
mu = [65, 150]  # [mean height, mean weight]
Sigma = [[9, 24], [24, 64]]  # Covariance matrix

# Check if Sigma is positive definite
if np.all(np.linalg.eigvals(Sigma) > 0):
    # If positive definite, proceed with the calculation
    # Define the bounds for height and weight
    height_bounds = [62, 68]
    weight_bounds = [140, 160]

    # Generate a grid for numerical integration
    height = np.linspace(height_bounds[0], height_bounds[1], 100)
    weight = np.linspace(weight_bounds[0], weight_bounds[1], 100)
    H, W = np.meshgrid(height, weight)

    # Stack the grid points and calculate the joint PDF
    pos = np.dstack((H, W))
    pdf = multivariate_normal(mean=mu, cov=Sigma).pdf(pos)

    # Approximate the probability by summing over the PDF and scaling by the grid size
    probability = pdf.sum() * (height[1] - height[0]) * (weight[1] - weight[0])

    # Output the result
    print("The probability that a randomly selected student has a height between 62 and 68 inches and a weight between 140 and 160 pounds:", probability)

# %% [markdown]
# ### **🎓Activity 4:**

# %% [markdown]
# Given the following set of data:
#
# X = {2, 4, 6, 8, 10}
#
# Y = {1, 3, 5, 7, 9}
#
# Calculate the covariance and correlation between X and Y.

# %%
import numpy as np

# Given Data

X = np.array([2, 4, 6, 8, 10])
Y = np.array([1, 3, 5, 7, 9])

# Calculate mean

mean_X = np.mean(X)
mean_Y = np.mean(Y)

# Calaculate covariance

covariance = np.mean((X - mean_X) * (Y - mean_Y))

# Calcualte Correlation

std_X = np.std(X, ddof = 0)
std_Y = np.std(Y, ddof = 0)
correlation = covariance / (std_X * std_Y)

# Output

print("Covariance between X and Y: ", covariance)
print("Correlation between X and Y: ", correlation)
# Out:
# Covariance between X and Y:  8.0
# Correlation between X and Y:  0.9999999999999998

# %% [markdown]
# ###**🎓 Activity 5: Insurance Cost Prediction 💸:**
#
#
#
#
#
#
# In this assignment, we will explore some statistical concepts using the Insurance Cost Prediction dataset from Kaggle. The dataset contains information on insurance cost for individuals based on their age, sex, BMI, number of children, smoking habit, and geographic region.
#
# 1. 📊 Load the dataset into a Pandas dataframe and display the first five rows of the dataset.
# Dataset link: https://www.kaggle.com/mirichoi0218/insurance
# 2. 📈 Plot the distribution of insurance charges for male and female policyholders.
# 3. 📐 Calculate the conditional distribution of insurance charges given the policyholder's smoking habit.
# 4. 📈 Create a scatter plot to visualize the relationship between BMI and insurance charges.
# 5. 📐 Compute the covariance and correlation between the policyholder's age and insurance charges.
# 6. 📈 Create a heatmap to visualize the covariance matrix of the dataset.
# 7. 📐 Fit a multivariate normal distribution to the dataset using the maximum likelihood estimation and visualize the contours of the distribution in a 2D plot.
#
# Note: Make sure to import all the necessary libraries such as pandas, numpy, matplotlib, seaborn, and scipy.

# %%
# Import necessary libraries
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from scipy.stats import multivariate_normal

# Load the dataset
from google.colab import drive
drive.mount('/content/drive')


# Display the first five rows of the dataset


# Task 2: Plot the distribution of insurance charges for male and female policyholders


# Task 3: Calculate the conditional distribution of insurance charges given the policyholder's smoking habit

# Task 4: Create a scatter plot to visualize the relationship between BMI and insurance charges


# Task 5: Compute the covariance and correlation between the policyholder's age and inchargessurance

# Task 6: Create a heatmap to visualize the covariance matrix of the dataset


# Task 7: Fit a multivariate normal distribution and visualize the contours in a 2D plot
# Select the features for the multivariate normal distribution


# Estimate the mean and covariance matrix using maximum likelihood estimation

# %%
# Import Necessary Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from scipy.stats import multivariate_normal

# %%
# Load the dataset

from google.colab import drive
drive.mount('/content/drive')

insurance = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/insurance.csv')

insurance
# Out:
# Mounted at /content/drive
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance.shape
# Out:
# (1338, 7)

# %%
# Display the first 5 row of dataset

insurance.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Task 2: Plot the distribution of insurance charges for male and female policyholders
sns.displot(data = insurance, x = 'charges', hue = 'sex', kind = 'kde')
plt.title('Distribution of Insurance Charges for Male and Female Policyholders')
plt.xlabel('Insurance Charges')
plt.ylabel('Density')
plt.show()

# %%
# Task 3: Calculate the conditional distribution of insurance charges given the policyholder's smoking habit

smoker_charges = insurance[insurance['smoker'] == 'yes']['charges']
non_smoker_charges = insurance[insurance['smoker'] == 'no']['charges']

print("Conditional Distribution of Insurance Charges for Smokers:")
print(smoker_charges.describe())

print("\nConditional Distribution of Insurance Charges for Non-Smokers:")
print(non_smoker_charges.describe())

plt.figure(figsize=(10, 6))
plt.hist(smoker_charges, bins=30, alpha=0.5, label='Smoker', density = True)
plt.hist(non_smoker_charges, bins=30, alpha=0.5, label='Non-Smoker', density = True)
plt.title('Distribution of Insurance Charges by Smoking Status')
plt.xlabel('Insurance Charges')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# Conditional Distribution of Insurance Charges for Smokers:
# count      274.000000
# mean     32050.231832
# std      11541.547176
# min      12829.455100
# 25%      20826.244213
# 50%      34456.348450
# 75%      41019.207275
# max      63770.428010
# Name: charges, dtype: float64
#
# Conditional Distribution of Insurance Charges for Non-Smokers:
# count     1064.000000
# mean      8434.268298
# std       5993.781819
# min       1121.873900
# 25%       3986.438700
# 50%       7345.405300
# 75%      11362.887050
# max      36910.608030
# Name: charges, dtype: float64

# %%
# Task 4: Create a scatter plot to visualize the relationship between BMI and insurance charges

plt.figure(figsize=(10, 6))
plt.scatter(insurance['bmi'], insurance['charges'])
plt.title('Relationship between BMI and Insurance Charges')
plt.xlabel('BMI')
plt.ylabel('Insurance Charges')
plt.show()

# %%
# Task 5: Compute the covariance and correlation between the policyholder's age and inchargessurance

# Calculate the covariance and correlation
covariance_age_charges = np.cov(insurance['age'], insurance['charges'])[0, 1]
correlation_age_charges = np.corrcoef(insurance['age'], insurance['charges'])[0, 1]

print(f"Covariance between age and charges: {covariance_age_charges}")
print(f"Correlation between age and charges: {correlation_age_charges}")
# Out:
# Covariance between age and charges: 50874.802297858536
# Correlation between age and charges: 0.29900819333064754

# %%
# Task 6: Create a heatmap to visualize the covariance matrix of the dataset
numeric_columns = insurance.select_dtypes(include=np.number)
covariance_matrix = numeric_columns.cov()

plt.figure(figsize=(8, 6))
sns.heatmap(covariance_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Covariance Matrix Heatmap')
plt.show()

# %%
# prompt: # Task 7: Fit a multivariate normal distribution and visualize the contours in a 2D plot

# Select features for the multivariate normal distribution
features = ['age', 'bmi', 'charges']
data = insurance[features]

# Estimate the mean and covariance matrix using maximum likelihood estimation
mu = data.mean().values
Sigma = data.cov().values

# Create the multivariate normal distribution
rv = multivariate_normal(mean=mu, cov=Sigma)

# Create a meshgrid for plotting
x, y = np.meshgrid(np.linspace(data['age'].min(), data['age'].max(), 100),
                   np.linspace(data['bmi'].min(), data['bmi'].max(), 100))
pos = np.empty(x.shape + (3,))
pos[:, :, 0] = x
pos[:, :, 1] = y
pos[:, :, 2] = data['charges'].mean()

# Calculate the probability density function (PDF) values for the meshgrid
pdf = rv.pdf(pos)


# Plot the contours
fig, ax = plt.subplots(figsize=(8,6))
ax.contour(x, y, pdf)

# Add labels and title
ax.set_xlabel('Age')
ax.set_ylabel('BMI')
ax.set_title('Contours of Multivariate Normal Distribution')

plt.show()

# %%
# Estimate the mean and covariance matrix using maximum likelihood estimation

# Select features for the multivariate normal distribution
features = ['age', 'bmi', 'charges']
data = insurance[features]

# Estimate the mean and covariance matrix using maximum likelihood estimation
mu = data.mean().values
Sigma = data.cov().values

print(mu, Sigma)
# Out:
# [   39.20702541    30.66339686 13270.42226514] [[1.97401387e+02 9.36233663e+00 5.08748023e+04]
#  [9.36233663e+00 3.71878836e+01 1.46473044e+04]
#  [5.08748023e+04 1.46473044e+04 1.46652372e+08]]

# %% [markdown]
# ## **Task 2**

# %% [markdown]
# **🔴Which question did you find challenging & Why, and How did you overcome it? Share your thoughts in your Cohort group at AlmaBetter Community Platform.🔴**
